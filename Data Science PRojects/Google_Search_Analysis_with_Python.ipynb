# %%
# pytrends is a Python library that acts as an unofficial API for Google Trends. It allows you to programmatically access and analyze search trends data from Google Trends.
import pandas as pd 
from pytrends.request import TrendReq 
import matplotlib.pyplot as plt 
Trending_topics = TrendReq(hl='en-IN', tz=330)

# %%
kw_list=["Data science"] 
Trending_topics.build_payload(kw_list,cat=0, timeframe='today 12-m')

Trending_topics.build_payload(kw_list=["Data science"], 
                              cat=0, timeframe='today 12-m') 
data = Trending_topics.interest_over_time() 
data = data.sort_values(by="Data science", ascending = False) 
data = data.head(50) 
print(data)
# Out:
#             Data science  isPartial
# date
# 2024-01-28           100      False
# 2023-08-20            99      False
# 2023-09-17            99      False
# 2024-01-21            98      False
# 2023-08-27            98      False
# 2024-03-17            96      False
# 2023-08-13            95      False
# 2023-07-09            95      False
# 2024-02-18            95      False
# 2024-05-12            95      False
# 2023-09-10            94      False
# 2024-02-04            94      False
# 2023-09-03            93      False
# 2023-07-23            93      False
# 2024-03-03            92      False
# 2024-05-19            92      False
# 2024-02-25            92      False
# 2024-03-24            92      False
# 2023-08-06            92      False
# 2023-09-24            92      False
# 2024-03-10            91      False
# 2024-04-21            91      False
# 2024-01-07            91      False
# 2023-07-16            90      False
# 2024-05-05            90      False
# ...

# %%
data = Trending_topics.interest_by_region() 
data = data.sort_values(by="Data science",  
                        ascending = False) 
data = data.head(50) 
print(data)
# Out:
#                       Data science
# geoName
# Zimbabwe                       100
# Kenya                           90
# India                           89
# Singapore                       72
# Ethiopia                        71
# Sri Lanka                       69
# Nigeria                         69
# Ghana                           67
# China                           63
# Nepal                           62
# Pakistan                        61
# Tunisia                         43
# South Korea                     39
# South Africa                    38
# Hong Kong                       36
# United Arab Emirates            35
# United States                   34
# Canada                          29
# Bangladesh                      29
# United Kingdom                  28
# Australia                       27
# Malaysia                        27
# Switzerland                     26
# Ireland                         26
# Morocco                         25
# ...

# %%
data.reset_index().plot(x='geoName', y='Data science', 
                        figsize=(10,5), kind="bar") 
plt.style.use('fivethirtyeight') 
plt.show()

# %%
df = Trending_topics.top_charts(2020, hl='en-IN',  
                                tz=300, geo='GLOBAL') 
df.head(50)
# Out:
#                   title exploreQuery
# 0           Coronavirus
# 1      Election results
# 2           Kobe Bryant
# 3                  Zoom
# 4                   IPL
# 5  India vs New Zealand
# 6    Coronavirus update
# 7  Coronavirus symptoms
# 8             Joe Biden
# 9      Google Classroom

# %%
# for trending keywords for the Data science 
keywords = Trending_topics.suggestions( 
  keyword='Data Science') 
df = pd.DataFrame(keywords) 
df.drop(columns= 'mid')
# Out:
#                                                title                      type
# 0                                       Data science            Field of study
# 1                            House of Sky and Breath     Book by Sarah J. Maas
# 2                             Master in Data Science                     Topic
# 3  Burn the Boats: Toss Plan B Overboard and Unle...      Book by Matt Higgins
# 4                              The Soulmate Equation  Book by Christina Lauren
